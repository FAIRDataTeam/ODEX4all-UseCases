# %% [markdown]
# ## Motivation: To identify genotype-phenotype relationships for yeast genes related to butanol tolerance using the Euretos Knowledge platform

# %% [markdown]
# ### Setup the Workflow Infrastructure

# %%
source("EuretosInfrastructure.R")
options(warn=-1)

# %% [markdown]
# #### DSM workflow starts here: Load Input data provided by DSM this data consists of a list of yeast genes and a list of terms that represent butanol tolerance

# %%
yeast_genes<-read.csv("yeast_genes_sgdID.csv",header=TRUE)
phenotype <- read.csv("/home/anandgavai/ODEX4all-UseCases/ODEX4all-UseCases/scripts/EKP/DSM/dropbox/Resistance_terms.txt",header=FALSE)
# separate onto columns
phenotype <- separate(data = phenotype, col = V1, into = c("terms", "class"), sep = "\tequals\t")

# %% [markdown]
# ## Step 1a : Get the starting concept identifiers

# %% [markdown]
# query = "/external/concepts/search"
# start<-getConceptID(as.character(yeast_genes[,1]))

# %% [markdown]
# ## Step 1b: Get the ending concept identifiers for "resistance to chemicals"

# %%
query = "/external/concepts/search"
end1 <- getConceptID("resistance to chemicals")

# %% [markdown]
# ## Step 1c: Get the ending concept identifiers for "butanol tolerance"

# %%
query = "/external/concepts/search"
end2 <- getConceptID("butanol tolerance")

# %% [markdown]
# ## Step 2a: Get Indirect relationships from EKP for ending terms "resistance to chemicals"

# %%
query = "/external/concepts/search"
end1 <- getConceptID("resistance to chemicals")

# %%
head(resistance2Chemicals)
# Out:
#   content.concepts.id content.concepts.name
# a 4042749             ucc1 (saccharomyces cerevisiae s288c)
# a 4044156             pro2 (saccharomyces cerevisiae s288c)
# a 4044156             pro2 (saccharomyces cerevisiae s288c)
# a 4043331             snx4 (saccharomyces cerevisiae s288c)
# a 4043331             snx4 (saccharomyces cerevisiae s288c)
# a 4044162             msn2 (saccharomyces cerevisiae s288c)
#   content.concepts.semanticCategory content.concepts.id content.concepts.name
# a Genes & Molecular Sequences       4964457             parachlorophenol
# a Genes & Molecular Sequences       4963583             urea
# a Genes & Molecular Sequences       4964457             parachlorophenol
# a Genes & Molecular Sequences       967758              polyphosphates
# a Genes & Molecular Sequences       5210546             calcofluor white
# a Genes & Molecular Sequences       1047802             cytoplasmic matrix
#   content.concepts.semanticCategory content.concepts.id
# a Chemicals & Drugs                 3461869
# a Chemicals & Drugs                 831196
# a Chemicals & Drugs                 3461869
# a Chemicals & Drugs                 831196
# a Chemicals & Drugs                 3461869
# a Anatomy                           831196
#   content.concepts.name                     content.concepts.semanticCategory
# a chemicals                                 Chemicals & Drugs
# a tryptophan 2,3-dioxygenase (homo sapiens) Chemicals & Drugs
# a chemicals                                 Chemicals & Drugs
# a tryptophan 2,3-dioxygenase (homo sapiens) Chemicals & Drugs
# a chemicals                                 Chemicals & Drugs
# a tryptophan 2,3-dioxygenase (homo sapiens) Chemicals & Drugs
#   content.relationships.concept0Id ⋯
# a 4042749                          ⋯
# a 4044156                          ⋯
# a 4044156                          ⋯
# a 4043331                          ⋯
# a 4043331                          ⋯
# a 4044162                          ⋯
#   content.relationships.concept0Id
# a 1288761
# a oxidoreductase activity, acting on other substrates
# a 5225041
# a diphosphates
# a 1134038
# a 1047802
#   content.relationships.concept1Id content.score
# a 3461869                          13.7088029326004
# a Physiology                       831196
# a 3461869                          11.6230756106485
# a Chemicals & Drugs                831196
# a 3461869                          12.3879766898607
# a 831196                           13.7965516756188
#   last
# a TRUE
# a tryptophan 2,3-dioxygenase (homo sapiens)
# a 4044156
# a tryptophan 2,3-dioxygenase (homo sapiens)
# a 4043331
# a 4044162
#   totalPages                            totalElements
# a 1                                     6
# a Chemicals & Drugs                     4044156
# a pro2 (saccharomyces cerevisiae s288c) Genes & Molecular Sequences
# a Chemicals & Drugs                     4043331
# a snx4 (saccharomyces cerevisiae s288c) Genes & Molecular Sequences
# a msn2 (saccharomyces cerevisiae s288c) Genes & Molecular Sequences
#   numberOfElements first               size              number
# a 6                TRUE                10                0
# a 279172           279172              831196            13.9772611399278
# a 696567           hydrogen sulfide    Chemicals & Drugs 3461869
# a 1262592          1262592             831196            11.4024287782839
# a 837632           dieldrin            Chemicals & Drugs 3461869
# a 249129           heavy metal binding Physiology        831196

# %% [markdown]
# ## Step 2b: Get Indirect relationships from EKP for ending terms "butanol tolerance"

# %%
query = "/external/concept-to-concept/indirect"
butanolTolerance<-getIndirectRelation(start,end2)

# %%
dim(butanolTolerance)
# Out:
# [1] 63 49

# %%
head(butanolTolerance)
# Out:
#   content.concepts.id content.concepts.name
# a 4042749             ucc1 (saccharomyces cerevisiae s288c)
# a 4042749             ucc1 (saccharomyces cerevisiae s288c)
# a 4042749             ucc1 (saccharomyces cerevisiae s288c)
# a 4042749             ucc1 (saccharomyces cerevisiae s288c)
# a 4044156             pro2 (saccharomyces cerevisiae s288c)
# a 4044156             pro2 (saccharomyces cerevisiae s288c)
#   content.concepts.semanticCategory content.concepts.id content.concepts.name
# a Genes & Molecular Sequences       588040              1-butanol
# a Genes & Molecular Sequences       1288761             sodium chloride
# a Genes & Molecular Sequences       4970313             sirolimus
# a Genes & Molecular Sequences       588040              1-butanol
# a Genes & Molecular Sequences       588040              1-butanol
# a Genes & Molecular Sequences       1288761             sodium chloride
#   content.concepts.semanticCategory content.concepts.id content.concepts.name
# a Chemicals & Drugs                 588040              1-butanol
# a Chemicals & Drugs                 3438887             physiologic tolerance
# a Chemicals & Drugs                 4056067             immune tolerance
# a Chemicals & Drugs                 5225634             butanols
# a Chemicals & Drugs                 588040              1-butanol
# a Chemicals & Drugs                 3438887             physiologic tolerance
#   content.concepts.semanticCategory content.relationships.concept0Id ⋯
# a Chemicals & Drugs                 4042749                          ⋯
# a Physiology                        4042749                          ⋯
# a Disorders                         4042749                          ⋯
# a Chemicals & Drugs                 4042749                          ⋯
# a Chemicals & Drugs                 4044156                          ⋯
# a Physiology                        4044156                          ⋯
#   content.relationships.concept0Id content.relationships.concept1Id
# a 1288761                          588040
# a TRUE                             10
# a TRUE                             10
# a 1-butanol                        Chemicals & Drugs
# a 4962734                          588040
# a TRUE                             10
#   content.score    last     totalPages
# a 12.9304933250657 TRUE     1
# a 0                4042749  ucc1 (saccharomyces cerevisiae s288c)
# a 0                4042749  ucc1 (saccharomyces cerevisiae s288c)
# a 5225634          butanols Chemicals & Drugs
# a 11.8690738083681 4044156  pro2 (saccharomyces cerevisiae s288c)
# a 0                4044156  pro2 (saccharomyces cerevisiae s288c)
#   totalElements               numberOfElements first
# a 3                           3                TRUE
# a Genes & Molecular Sequences 1288761          sodium chloride
# a Genes & Molecular Sequences 4970313          sirolimus
# a 4042749                     588040           588040
# a Genes & Molecular Sequences 5258250          resistance to chemicals
# a Genes & Molecular Sequences 1288761          sodium chloride
#   size              number
# a 10                0
# a Chemicals & Drugs 3438887
# a Chemicals & Drugs 4056067
# a 5225634           10.2934774029667
# a Physiology        588040
# a Chemicals & Drugs 3438887

# %% [markdown]
# ## Step 3 : Find the intersections of these relationships based on ?

# %% [markdown]
# ## Alternative approach

# %% [markdown]
# ## Get phenotype terms from the list provided by DSM and do the above anal
