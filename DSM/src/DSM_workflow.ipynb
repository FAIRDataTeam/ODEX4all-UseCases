# %% [markdown]
# ## Objective: To identify genotype-phenotype trait association in yeast
# ### Develop a workflow to identify genes indirectly associated with a certain yeast phenotype (butanol tolerance) usint EKP and visualize them in an interactive knowledge graph

# %% [markdown]
# ### Load the API scripts with login credentials

# %%
library(dplyr)
library(tidyr)
library(sqldf)
source("EuretosInfrastructure.R")
options(warn=-1)
# Out:
# Retrieving page 0
# Retrieving page 1
# Retrieving page 2
# Retrieving page 3
# Retrieving page 4
# Retrieving page 5
# Retrieving page 6
# Retrieving page 7
# Retrieving page 8
# Retrieving page 9
# Retrieving page 10
# Retrieving page 11

# %% [markdown]
# ### DSM workflow starts here:
# ### Load Input data provided by DSM this data consists of a list of yeast genes and a list of terms that represent butanol tolerance

# %%
yeast_genes<-read.csv("yeast_genes_sgdID.csv",header=TRUE)

# %% [markdown]
# ## Step 1a : Get the starting concept identifiers

# %%
query = "/external/concepts/search"
start<-getConceptID(as.character(yeast_genes[,1]))

# %%
head(start)
# Out:
#   Id         EKP_Concept_Id name
# 1 s000004214 4042749        ucc1 (saccharomyces cerevisiae s288c)
# 2 s000005850 4044156        pro2 (saccharomyces cerevisiae s288c)
# 3 s000003573 4043331        snx4 (saccharomyces cerevisiae s288c)
# 4 s000004640 4044162        msn2 (saccharomyces cerevisiae s288c)
# 5 s000001086 4045917        dog1 (saccharomyces cerevisiae s288c)
# 6 s000005393 4044097        mse1 (saccharomyces cerevisiae s288c)

# %% [markdown]
# ## Step 1b: Get the ending concept identifiers for "resistance to chemicals"

# %%
query = "/external/concepts/search"
end <- getConceptID("resistance to chemicals")

# %%
head(end)
# Out:
#   Id                      EKP_Concept_Id
# 1 resistance to chemicals 41742
# 2 resistance to chemicals 640662
# 3 resistance to chemicals 702742
# 4 resistance to chemicals 831196
# 5 resistance to chemicals 1226570
# 6 resistance to chemicals 2862982
#   name
# 1 social resistance
# 2 tonga (geographic area)
# 3 togo
# 4 tryptophan 2,3-dioxygenase (homo sapiens)
# 5 toxicity aspects
# 6 resistance process

# %% [markdown]
# ## Step 2: Get Indirect relationships from EKP for ending terms "resistance to chemicals"

# %%
resistance2Chemicals<-getIndirectRelation(start,end)

df<-fromJSON(toJSON(resistance2Chemicals),flatten=TRUE)

do.call(rbind,df) %>% as.data.frame ->b

# %%
head(resistance2Chemicals)
# Out:
# [[1]]
# NULL
#
# [[2]]
# [[2]][[1]]
# [[2]][[1]]$concepts
# [[2]][[1]]$concepts[[1]]
# [[2]][[1]]$concepts[[1]]$id
# [1] "4042749"
#
# [[2]][[1]]$concepts[[1]]$name
# [1] "ucc1 (saccharomyces cerevisiae s288c)"
#
# [[2]][[1]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[2]][[1]]$concepts[[2]]
# [[2]][[1]]$concepts[[2]]$id
# [1] "4964457"
#
# [[2]][[1]]$concepts[[2]]$name
# [1] "parachlorophenol"
#
# [[2]][[1]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[2]][[1]]$concepts[[3]]
# [[2]][[1]]$concepts[[3]]$id
# [1] "3461869"
#
# [[2]][[1]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[2]][[1]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[2]][[1]]$relationships
# [[2]][[1]]$relationships[[1]]
# [[2]][[1]]$relationships[[1]]$concept0Id
# [1] "4042749"
#
# [[2]][[1]]$relationships[[1]]$concept1Id
# [1] "4964457"
#
# [[2]][[1]]$relationships[[1]]$predicateIds
# [[2]][[1]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[2]][[1]]$relationships[[2]]
# [[2]][[1]]$relationships[[2]]$concept0Id
# [1] "4964457"
#
# [[2]][[1]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[2]][[1]]$relationships[[2]]$predicateIds
# [[2]][[1]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
#
#
#
# [[2]][[1]]$score
# [1] 10.19253
#
#
# [[2]][[2]]
# [[2]][[2]]$concepts
# [[2]][[2]]$concepts[[1]]
# [[2]][[2]]$concepts[[1]]$id
# [1] "4042749"
#
# [[2]][[2]]$concepts[[1]]$name
# [1] "ucc1 (saccharomyces cerevisiae s288c)"
#
# [[2]][[2]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[2]][[2]]$concepts[[2]]
# [[2]][[2]]$concepts[[2]]$id
# [1] "588040"
#
# [[2]][[2]]$concepts[[2]]$name
# [1] "1-butanol"
#
# [[2]][[2]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[2]][[2]]$concepts[[3]]
# [[2]][[2]]$concepts[[3]]$id
# [1] "3461869"
#
# [[2]][[2]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[2]][[2]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[2]][[2]]$relationships
# [[2]][[2]]$relationships[[1]]
# [[2]][[2]]$relationships[[1]]$concept0Id
# [1] "4042749"
#
# [[2]][[2]]$relationships[[1]]$concept1Id
# [1] "588040"
#
# [[2]][[2]]$relationships[[1]]$predicateIds
# [[2]][[2]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[2]][[2]]$relationships[[2]]
# [[2]][[2]]$relationships[[2]]$concept0Id
# [1] "588040"
#
# [[2]][[2]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[2]][[2]]$relationships[[2]]$predicateIds
# [[2]][[2]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
# [[2]][[2]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[2]][[2]]$score
# [1] 11.19263
#
#
# [[2]][[3]]
# [[2]][[3]]$concepts
# [[2]][[3]]$concepts[[1]]
# [[2]][[3]]$concepts[[1]]$id
# [1] "4042749"
#
# [[2]][[3]]$concepts[[1]]$name
# [1] "ucc1 (saccharomyces cerevisiae s288c)"
#
# [[2]][[3]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[2]][[3]]$concepts[[2]]
# [[2]][[3]]$concepts[[2]]$id
# [1] "834346"
#
# [[2]][[3]]$concepts[[2]]$name
# [1] "toxaphene"
#
# [[2]][[3]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[2]][[3]]$concepts[[3]]
# [[2]][[3]]$concepts[[3]]$id
# [1] "3461869"
#
# [[2]][[3]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[2]][[3]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[2]][[3]]$relationships
# [[2]][[3]]$relationships[[1]]
# [[2]][[3]]$relationships[[1]]$concept0Id
# [1] "4042749"
#
# [[2]][[3]]$relationships[[1]]$concept1Id
# [1] "834346"
#
# [[2]][[3]]$relationships[[1]]$predicateIds
# [[2]][[3]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[2]][[3]]$relationships[[2]]
# [[2]][[3]]$relationships[[2]]$concept0Id
# [1] "834346"
#
# [[2]][[3]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[2]][[3]]$relationships[[2]]$predicateIds
# [[2]][[3]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
#
#
#
# [[2]][[3]]$score
# [1] 11.25141
#
#
# [[2]][[4]]
# [[2]][[4]]$concepts
# [[2]][[4]]$concepts[[1]]
# [[2]][[4]]$concepts[[1]]$id
# [1] "4042749"
#
# [[2]][[4]]$concepts[[1]]$name
# [1] "ucc1 (saccharomyces cerevisiae s288c)"
#
# [[2]][[4]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[2]][[4]]$concepts[[2]]
# [[2]][[4]]$concepts[[2]]$id
# [1] "5225041"
#
# [[2]][[4]]$concepts[[2]]$name
# [1] "benomyl"
#
# [[2]][[4]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[2]][[4]]$concepts[[3]]
# [[2]][[4]]$concepts[[3]]$id
# [1] "3461869"
#
# [[2]][[4]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[2]][[4]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[2]][[4]]$relationships
# [[2]][[4]]$relationships[[1]]
# [[2]][[4]]$relationships[[1]]$concept0Id
# [1] "4042749"
#
# [[2]][[4]]$relationships[[1]]$concept1Id
# [1] "5225041"
#
# [[2]][[4]]$relationships[[1]]$predicateIds
# [[2]][[4]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[2]][[4]]$relationships[[2]]
# [[2]][[4]]$relationships[[2]]$concept0Id
# [1] "5225041"
#
# [[2]][[4]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[2]][[4]]$relationships[[2]]$predicateIds
# [[2]][[4]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[2]][[4]]$relationships[[2]]$predicateIds[[2]]
# [1] "34"
#
# [[2]][[4]]$relationships[[2]]$predicateIds[[3]]
# [1] "3"
#
#
#
#
# [[2]][[4]]$score
# [1] 11.36216
#
#
# [[2]][[5]]
# [[2]][[5]]$concepts
# [[2]][[5]]$concepts[[1]]
# [[2]][[5]]$concepts[[1]]$id
# [1] "4042749"
#
# [[2]][[5]]$concepts[[1]]$name
# [1] "ucc1 (saccharomyces cerevisiae s288c)"
#
# [[2]][[5]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[2]][[5]]$concepts[[2]]
# [[2]][[5]]$concepts[[2]]$id
# [1] "4970313"
#
# [[2]][[5]]$concepts[[2]]$name
# [1] "sirolimus"
#
# [[2]][[5]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[2]][[5]]$concepts[[3]]
# [[2]][[5]]$concepts[[3]]$id
# [1] "3461869"
#
# [[2]][[5]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[2]][[5]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[2]][[5]]$relationships
# [[2]][[5]]$relationships[[1]]
# [[2]][[5]]$relationships[[1]]$concept0Id
# [1] "4042749"
#
# [[2]][[5]]$relationships[[1]]$concept1Id
# [1] "4970313"
#
# [[2]][[5]]$relationships[[1]]$predicateIds
# [[2]][[5]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[2]][[5]]$relationships[[2]]
# [[2]][[5]]$relationships[[2]]$concept0Id
# [1] "4970313"
#
# [[2]][[5]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[2]][[5]]$relationships[[2]]$predicateIds
# [[2]][[5]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
#
#
#
# [[2]][[5]]$score
# [1] 12.75681
#
#
# [[2]][[6]]
# [[2]][[6]]$concepts
# [[2]][[6]]$concepts[[1]]
# [[2]][[6]]$concepts[[1]]$id
# [1] "4042749"
#
# [[2]][[6]]$concepts[[1]]$name
# [1] "ucc1 (saccharomyces cerevisiae s288c)"
#
# [[2]][[6]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[2]][[6]]$concepts[[2]]
# [[2]][[6]]$concepts[[2]]$id
# [1] "1288761"
#
# [[2]][[6]]$concepts[[2]]$name
# [1] "sodium chloride"
#
# [[2]][[6]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[2]][[6]]$concepts[[3]]
# [[2]][[6]]$concepts[[3]]$id
# [1] "3461869"
#
# [[2]][[6]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[2]][[6]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[2]][[6]]$relationships
# [[2]][[6]]$relationships[[1]]
# [[2]][[6]]$relationships[[1]]$concept0Id
# [1] "4042749"
#
# [[2]][[6]]$relationships[[1]]$concept1Id
# [1] "1288761"
#
# [[2]][[6]]$relationships[[1]]$predicateIds
# [[2]][[6]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[2]][[6]]$relationships[[2]]
# [[2]][[6]]$relationships[[2]]$concept0Id
# [1] "1288761"
#
# [[2]][[6]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[2]][[6]]$relationships[[2]]$predicateIds
# [[2]][[6]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[2]][[6]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
# [[2]][[6]]$relationships[[2]]$predicateIds[[3]]
# [1] "34"
#
#
#
#
# [[2]][[6]]$score
# [1] 13.7088
#
#
#
# [[3]]
# [[3]][[1]]
# [[3]][[1]]$concepts
# [[3]][[1]]$concepts[[1]]
# [[3]][[1]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[1]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[1]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[1]]$concepts[[2]]
# [[3]][[1]]$concepts[[2]]$id
# [1] "4964457"
#
# [[3]][[1]]$concepts[[2]]$name
# [1] "parachlorophenol"
#
# [[3]][[1]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[1]]$concepts[[3]]
# [[3]][[1]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[1]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[1]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[1]]$relationships
# [[3]][[1]]$relationships[[1]]
# [[3]][[1]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[1]]$relationships[[1]]$concept1Id
# [1] "4964457"
#
# [[3]][[1]]$relationships[[1]]$predicateIds
# [[3]][[1]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[1]]$relationships[[2]]
# [[3]][[1]]$relationships[[2]]$concept0Id
# [1] "4964457"
#
# [[3]][[1]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[1]]$relationships[[2]]$predicateIds
# [[3]][[1]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
#
#
#
# [[3]][[1]]$score
# [1] 10.45344
#
#
# [[3]][[2]]
# [[3]][[2]]$concepts
# [[3]][[2]]$concepts[[1]]
# [[3]][[2]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[2]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[2]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[2]]$concepts[[2]]
# [[3]][[2]]$concepts[[2]]$id
# [1] "588040"
#
# [[3]][[2]]$concepts[[2]]$name
# [1] "1-butanol"
#
# [[3]][[2]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[2]]$concepts[[3]]
# [[3]][[2]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[2]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[2]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[2]]$relationships
# [[3]][[2]]$relationships[[1]]
# [[3]][[2]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[2]]$relationships[[1]]$concept1Id
# [1] "588040"
#
# [[3]][[2]]$relationships[[1]]$predicateIds
# [[3]][[2]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[2]]$relationships[[2]]
# [[3]][[2]]$relationships[[2]]$concept0Id
# [1] "588040"
#
# [[3]][[2]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[2]]$relationships[[2]]$predicateIds
# [[3]][[2]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
# [[3]][[2]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[3]][[2]]$score
# [1] 11.45354
#
#
# [[3]][[3]]
# [[3]][[3]]$concepts
# [[3]][[3]]$concepts[[1]]
# [[3]][[3]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[3]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[3]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[3]]$concepts[[2]]
# [[3]][[3]]$concepts[[2]]$id
# [1] "1110692"
#
# [[3]][[3]]$concepts[[2]]$name
# [1] "congo red"
#
# [[3]][[3]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[3]]$concepts[[3]]
# [[3]][[3]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[3]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[3]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[3]]$relationships
# [[3]][[3]]$relationships[[1]]
# [[3]][[3]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[3]]$relationships[[1]]$concept1Id
# [1] "1110692"
#
# [[3]][[3]]$relationships[[1]]$predicateIds
# [[3]][[3]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[3]]$relationships[[2]]
# [[3]][[3]]$relationships[[2]]$concept0Id
# [1] "1110692"
#
# [[3]][[3]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[3]]$relationships[[2]]$predicateIds
# [[3]][[3]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
#
#
#
# [[3]][[3]]$score
# [1] 11.45639
#
#
# [[3]][[4]]
# [[3]][[4]]$concepts
# [[3]][[4]]$concepts[[1]]
# [[3]][[4]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[4]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[4]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[4]]$concepts[[2]]
# [[3]][[4]]$concepts[[2]]$id
# [1] "1264076"
#
# [[3]][[4]]$concepts[[2]]$name
# [1] "amitrole"
#
# [[3]][[4]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[4]]$concepts[[3]]
# [[3]][[4]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[4]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[4]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[4]]$relationships
# [[3]][[4]]$relationships[[1]]
# [[3]][[4]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[4]]$relationships[[1]]$concept1Id
# [1] "1264076"
#
# [[3]][[4]]$relationships[[1]]$predicateIds
# [[3]][[4]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[4]]$relationships[[2]]
# [[3]][[4]]$relationships[[2]]$concept0Id
# [1] "1264076"
#
# [[3]][[4]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[4]]$relationships[[2]]$predicateIds
# [[3]][[4]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
#
#
#
# [[3]][[4]]$score
# [1] 11.47698
#
#
# [[3]][[5]]
# [[3]][[5]]$concepts
# [[3]][[5]]$concepts[[1]]
# [[3]][[5]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[5]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[5]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[5]]$concepts[[2]]
# [[3]][[5]]$concepts[[2]]$id
# [1] "4055907"
#
# [[3]][[5]]$concepts[[2]]$name
# [1] "idarubicin"
#
# [[3]][[5]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[5]]$concepts[[3]]
# [[3]][[5]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[5]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[5]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[5]]$relationships
# [[3]][[5]]$relationships[[1]]
# [[3]][[5]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[5]]$relationships[[1]]$concept1Id
# [1] "4055907"
#
# [[3]][[5]]$relationships[[1]]$predicateIds
# [[3]][[5]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[5]]$relationships[[2]]
# [[3]][[5]]$relationships[[2]]$concept0Id
# [1] "4055907"
#
# [[3]][[5]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[5]]$relationships[[2]]$predicateIds
# [[3]][[5]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
#
#
#
# [[3]][[5]]$score
# [1] 11.55985
#
#
# [[3]][[6]]
# [[3]][[6]]$concepts
# [[3]][[6]]$concepts[[1]]
# [[3]][[6]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[6]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[6]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[6]]$concepts[[2]]
# [[3]][[6]]$concepts[[2]]$id
# [1] "5225041"
#
# [[3]][[6]]$concepts[[2]]$name
# [1] "benomyl"
#
# [[3]][[6]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[6]]$concepts[[3]]
# [[3]][[6]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[6]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[6]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[6]]$relationships
# [[3]][[6]]$relationships[[1]]
# [[3]][[6]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[6]]$relationships[[1]]$concept1Id
# [1] "5225041"
#
# [[3]][[6]]$relationships[[1]]$predicateIds
# [[3]][[6]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[6]]$relationships[[2]]
# [[3]][[6]]$relationships[[2]]$concept0Id
# [1] "5225041"
#
# [[3]][[6]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[6]]$relationships[[2]]$predicateIds
# [[3]][[6]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[3]][[6]]$relationships[[2]]$predicateIds[[2]]
# [1] "34"
#
# [[3]][[6]]$relationships[[2]]$predicateIds[[3]]
# [1] "3"
#
#
#
#
# [[3]][[6]]$score
# [1] 11.62308
#
#
# [[3]][[7]]
# [[3]][[7]]$concepts
# [[3]][[7]]$concepts[[1]]
# [[3]][[7]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[7]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[7]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[7]]$concepts[[2]]
# [[3]][[7]]$concepts[[2]]$id
# [1] "696567"
#
# [[3]][[7]]$concepts[[2]]$name
# [1] "hydrogen sulfide"
#
# [[3]][[7]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[7]]$concepts[[3]]
# [[3]][[7]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[7]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[7]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[7]]$relationships
# [[3]][[7]]$relationships[[1]]
# [[3]][[7]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[7]]$relationships[[1]]$concept1Id
# [1] "696567"
#
# [[3]][[7]]$relationships[[1]]$predicateIds
# [[3]][[7]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[7]]$relationships[[2]]
# [[3]][[7]]$relationships[[2]]$concept0Id
# [1] "696567"
#
# [[3]][[7]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[7]]$relationships[[2]]$predicateIds
# [[3]][[7]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[3]][[7]]$relationships[[2]]$predicateIds[[2]]
# [1] "34"
#
# [[3]][[7]]$relationships[[2]]$predicateIds[[3]]
# [1] "34"
#
#
#
#
# [[3]][[7]]$score
# [1] 11.81768
#
#
# [[3]][[8]]
# [[3]][[8]]$concepts
# [[3]][[8]]$concepts[[1]]
# [[3]][[8]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[8]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[8]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[8]]$concepts[[2]]
# [[3]][[8]]$concepts[[2]]$id
# [1] "799920"
#
# [[3]][[8]]$concepts[[2]]$name
# [1] "neomycin"
#
# [[3]][[8]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[8]]$concepts[[3]]
# [[3]][[8]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[8]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[8]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[8]]$relationships
# [[3]][[8]]$relationships[[1]]
# [[3]][[8]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[8]]$relationships[[1]]$concept1Id
# [1] "799920"
#
# [[3]][[8]]$relationships[[1]]$predicateIds
# [[3]][[8]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[8]]$relationships[[2]]
# [[3]][[8]]$relationships[[2]]$concept0Id
# [1] "799920"
#
# [[3]][[8]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[8]]$relationships[[2]]$predicateIds
# [[3]][[8]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
# [[3]][[8]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[3]][[8]]$score
# [1] 12.07765
#
#
# [[3]][[9]]
# [[3]][[9]]$concepts
# [[3]][[9]]$concepts[[1]]
# [[3]][[9]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[9]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[9]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[9]]$concepts[[2]]
# [[3]][[9]]$concepts[[2]]$id
# [1] "696073"
#
# [[3]][[9]]$concepts[[2]]$name
# [1] "inorganic phosphate"
#
# [[3]][[9]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[9]]$concepts[[3]]
# [[3]][[9]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[9]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[9]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[9]]$relationships
# [[3]][[9]]$relationships[[1]]
# [[3]][[9]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[9]]$relationships[[1]]$concept1Id
# [1] "696073"
#
# [[3]][[9]]$relationships[[1]]$predicateIds
# [[3]][[9]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[9]]$relationships[[2]]
# [[3]][[9]]$relationships[[2]]$concept0Id
# [1] "696073"
#
# [[3]][[9]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[9]]$relationships[[2]]$predicateIds
# [[3]][[9]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[3]][[9]]$relationships[[2]]$predicateIds[[2]]
# [1] "109"
#
# [[3]][[9]]$relationships[[2]]$predicateIds[[3]]
# [1] "34"
#
#
#
#
# [[3]][[9]]$score
# [1] 12.29784
#
#
# [[3]][[10]]
# [[3]][[10]]$concepts
# [[3]][[10]]$concepts[[1]]
# [[3]][[10]]$concepts[[1]]$id
# [1] "4044156"
#
# [[3]][[10]]$concepts[[1]]$name
# [1] "pro2 (saccharomyces cerevisiae s288c)"
#
# [[3]][[10]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[3]][[10]]$concepts[[2]]
# [[3]][[10]]$concepts[[2]]$id
# [1] "993360"
#
# [[3]][[10]]$concepts[[2]]$name
# [1] "chitosan"
#
# [[3]][[10]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[3]][[10]]$concepts[[3]]
# [[3]][[10]]$concepts[[3]]$id
# [1] "3461869"
#
# [[3]][[10]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[3]][[10]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[3]][[10]]$relationships
# [[3]][[10]]$relationships[[1]]
# [[3]][[10]]$relationships[[1]]$concept0Id
# [1] "4044156"
#
# [[3]][[10]]$relationships[[1]]$concept1Id
# [1] "993360"
#
# [[3]][[10]]$relationships[[1]]$predicateIds
# [[3]][[10]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[3]][[10]]$relationships[[2]]
# [[3]][[10]]$relationships[[2]]$concept0Id
# [1] "993360"
#
# [[3]][[10]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[3]][[10]]$relationships[[2]]$predicateIds
# [[3]][[10]]$relationships[[2]]$predicateIds[[1]]
# [1] "142"
#
# [[3]][[10]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
# [[3]][[10]]$relationships[[2]]$predicateIds[[3]]
# [1] "34"
#
#
#
#
# [[3]][[10]]$score
# [1] 12.32926
#
#
#
# [[4]]
# [[4]][[1]]
# [[4]][[1]]$concepts
# [[4]][[1]]$concepts[[1]]
# [[4]][[1]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[1]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[1]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[1]]$concepts[[2]]
# [[4]][[1]]$concepts[[2]]$id
# [1] "5210546"
#
# [[4]][[1]]$concepts[[2]]$name
# [1] "calcofluor white"
#
# [[4]][[1]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[1]]$concepts[[3]]
# [[4]][[1]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[1]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[1]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[1]]$relationships
# [[4]][[1]]$relationships[[1]]
# [[4]][[1]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[1]]$relationships[[1]]$concept1Id
# [1] "5210546"
#
# [[4]][[1]]$relationships[[1]]$predicateIds
# [[4]][[1]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[1]]$relationships[[2]]
# [[4]][[1]]$relationships[[2]]$concept0Id
# [1] "5210546"
#
# [[4]][[1]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[1]]$relationships[[2]]$predicateIds
# [[4]][[1]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[4]][[1]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[4]][[1]]$score
# [1] 11.31718
#
#
# [[4]][[2]]
# [[4]][[2]]$concepts
# [[4]][[2]]$concepts[[1]]
# [[4]][[2]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[2]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[2]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[2]]$concepts[[2]]
# [[4]][[2]]$concepts[[2]]$id
# [1] "967758"
#
# [[4]][[2]]$concepts[[2]]$name
# [1] "polyphosphates"
#
# [[4]][[2]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[2]]$concepts[[3]]
# [[4]][[2]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[2]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[2]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[2]]$relationships
# [[4]][[2]]$relationships[[1]]
# [[4]][[2]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[2]]$relationships[[1]]$concept1Id
# [1] "967758"
#
# [[4]][[2]]$relationships[[1]]$predicateIds
# [[4]][[2]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[2]]$relationships[[2]]
# [[4]][[2]]$relationships[[2]]$concept0Id
# [1] "967758"
#
# [[4]][[2]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[2]]$relationships[[2]]$predicateIds
# [[4]][[2]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
# [[4]][[2]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[4]][[2]]$score
# [1] 11.68289
#
#
# [[4]][[3]]
# [[4]][[3]]$concepts
# [[4]][[3]]$concepts[[1]]
# [[4]][[3]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[3]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[3]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[3]]$concepts[[2]]
# [[4]][[3]]$concepts[[2]]$id
# [1] "94641"
#
# [[4]][[3]]$concepts[[2]]$name
# [1] "sodium cation"
#
# [[4]][[3]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[3]]$concepts[[3]]
# [[4]][[3]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[3]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[3]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[3]]$relationships
# [[4]][[3]]$relationships[[1]]
# [[4]][[3]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[3]]$relationships[[1]]$concept1Id
# [1] "94641"
#
# [[4]][[3]]$relationships[[1]]$predicateIds
# [[4]][[3]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[3]]$relationships[[2]]
# [[4]][[3]]$relationships[[2]]$concept0Id
# [1] "94641"
#
# [[4]][[3]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[3]]$relationships[[2]]$predicateIds
# [[4]][[3]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
#
#
#
# [[4]][[3]]$score
# [1] 11.78048
#
#
# [[4]][[4]]
# [[4]][[4]]$concepts
# [[4]][[4]]$concepts[[1]]
# [[4]][[4]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[4]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[4]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[4]]$concepts[[2]]
# [[4]][[4]]$concepts[[2]]$id
# [1] "4982009"
#
# [[4]][[4]]$concepts[[2]]$name
# [1] "cordycepin"
#
# [[4]][[4]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[4]]$concepts[[3]]
# [[4]][[4]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[4]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[4]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[4]]$relationships
# [[4]][[4]]$relationships[[1]]
# [[4]][[4]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[4]]$relationships[[1]]$concept1Id
# [1] "4982009"
#
# [[4]][[4]]$relationships[[1]]$predicateIds
# [[4]][[4]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[4]]$relationships[[2]]
# [[4]][[4]]$relationships[[2]]$concept0Id
# [1] "4982009"
#
# [[4]][[4]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[4]]$relationships[[2]]$predicateIds
# [[4]][[4]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
#
#
#
# [[4]][[4]]$score
# [1] 11.8006
#
#
# [[4]][[5]]
# [[4]][[5]]$concepts
# [[4]][[5]]$concepts[[1]]
# [[4]][[5]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[5]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[5]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[5]]$concepts[[2]]
# [[4]][[5]]$concepts[[2]]$id
# [1] "654733"
#
# [[4]][[5]]$concepts[[2]]$name
# [1] "zinc chloride"
#
# [[4]][[5]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[5]]$concepts[[3]]
# [[4]][[5]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[5]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[5]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[5]]$relationships
# [[4]][[5]]$relationships[[1]]
# [[4]][[5]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[5]]$relationships[[1]]$concept1Id
# [1] "654733"
#
# [[4]][[5]]$relationships[[1]]$predicateIds
# [[4]][[5]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[5]]$relationships[[2]]
# [[4]][[5]]$relationships[[2]]$concept0Id
# [1] "654733"
#
# [[4]][[5]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[5]]$relationships[[2]]$predicateIds
# [[4]][[5]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
#
#
#
# [[4]][[5]]$score
# [1] 12.35109
#
#
# [[4]][[6]]
# [[4]][[6]]$concepts
# [[4]][[6]]$concepts[[1]]
# [[4]][[6]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[6]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[6]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[6]]$concepts[[2]]
# [[4]][[6]]$concepts[[2]]$id
# [1] "1134038"
#
# [[4]][[6]]$concepts[[2]]$name
# [1] "spermine"
#
# [[4]][[6]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[6]]$concepts[[3]]
# [[4]][[6]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[6]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[6]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[6]]$relationships
# [[4]][[6]]$relationships[[1]]
# [[4]][[6]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[6]]$relationships[[1]]$concept1Id
# [1] "1134038"
#
# [[4]][[6]]$relationships[[1]]$predicateIds
# [[4]][[6]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[6]]$relationships[[2]]
# [[4]][[6]]$relationships[[2]]$concept0Id
# [1] "1134038"
#
# [[4]][[6]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[6]]$relationships[[2]]$predicateIds
# [[4]][[6]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[4]][[6]]$relationships[[2]]$predicateIds[[2]]
# [1] "34"
#
#
#
#
# [[4]][[6]]$score
# [1] 12.38798
#
#
# [[4]][[7]]
# [[4]][[7]]$concepts
# [[4]][[7]]$concepts[[1]]
# [[4]][[7]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[7]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[7]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[7]]$concepts[[2]]
# [[4]][[7]]$concepts[[2]]$id
# [1] "837632"
#
# [[4]][[7]]$concepts[[2]]$name
# [1] "dieldrin"
#
# [[4]][[7]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[7]]$concepts[[3]]
# [[4]][[7]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[7]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[7]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[7]]$relationships
# [[4]][[7]]$relationships[[1]]
# [[4]][[7]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[7]]$relationships[[1]]$concept1Id
# [1] "837632"
#
# [[4]][[7]]$relationships[[1]]$predicateIds
# [[4]][[7]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[7]]$relationships[[2]]
# [[4]][[7]]$relationships[[2]]$concept0Id
# [1] "837632"
#
# [[4]][[7]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[7]]$relationships[[2]]$predicateIds
# [[4]][[7]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[4]][[7]]$relationships[[2]]$predicateIds[[2]]
# [1] "34"
#
#
#
#
# [[4]][[7]]$score
# [1] 12.42475
#
#
# [[4]][[8]]
# [[4]][[8]]$concepts
# [[4]][[8]]$concepts[[1]]
# [[4]][[8]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[8]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[8]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[8]]$concepts[[2]]
# [[4]][[8]]$concepts[[2]]$id
# [1] "1288636"
#
# [[4]][[8]]$concepts[[2]]$name
# [1] "niacinamide"
#
# [[4]][[8]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[8]]$concepts[[3]]
# [[4]][[8]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[8]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[8]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[8]]$relationships
# [[4]][[8]]$relationships[[1]]
# [[4]][[8]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[8]]$relationships[[1]]$concept1Id
# [1] "1288636"
#
# [[4]][[8]]$relationships[[1]]$predicateIds
# [[4]][[8]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[8]]$relationships[[2]]
# [[4]][[8]]$relationships[[2]]$concept0Id
# [1] "1288636"
#
# [[4]][[8]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[8]]$relationships[[2]]$predicateIds
# [[4]][[8]]$relationships[[2]]$predicateIds[[1]]
# [1] "109"
#
#
#
#
# [[4]][[8]]$score
# [1] 12.43644
#
#
# [[4]][[9]]
# [[4]][[9]]$concepts
# [[4]][[9]]$concepts[[1]]
# [[4]][[9]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[9]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[9]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[9]]$concepts[[2]]
# [[4]][[9]]$concepts[[2]]$id
# [1] "5215793"
#
# [[4]][[9]]$concepts[[2]]$name
# [1] "arsenite"
#
# [[4]][[9]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[4]][[9]]$concepts[[3]]
# [[4]][[9]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[9]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[9]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[9]]$relationships
# [[4]][[9]]$relationships[[1]]
# [[4]][[9]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[9]]$relationships[[1]]$concept1Id
# [1] "5215793"
#
# [[4]][[9]]$relationships[[1]]$predicateIds
# [[4]][[9]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[4]][[9]]$relationships[[2]]
# [[4]][[9]]$relationships[[2]]$concept0Id
# [1] "5215793"
#
# [[4]][[9]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[9]]$relationships[[2]]$predicateIds
# [[4]][[9]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[4]][[9]]$relationships[[2]]$predicateIds[[2]]
# [1] "110"
#
# [[4]][[9]]$relationships[[2]]$predicateIds[[3]]
# [1] "34"
#
# [[4]][[9]]$relationships[[2]]$predicateIds[[4]]
# [1] "109"
#
# [[4]][[9]]$relationships[[2]]$predicateIds[[5]]
# [1] "3"
#
#
#
#
# [[4]][[9]]$score
# [1] 12.7099
#
#
# [[4]][[10]]
# [[4]][[10]]$concepts
# [[4]][[10]]$concepts[[1]]
# [[4]][[10]]$concepts[[1]]$id
# [1] "4043331"
#
# [[4]][[10]]$concepts[[1]]$name
# [1] "snx4 (saccharomyces cerevisiae s288c)"
#
# [[4]][[10]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[4]][[10]]$concepts[[2]]
# [[4]][[10]]$concepts[[2]]$id
# [1] "4053505"
#
# [[4]][[10]]$concepts[[2]]$name
# [1] "endocytosis"
#
# [[4]][[10]]$concepts[[2]]$semanticCategory
# [1] "Physiology"
#
#
# [[4]][[10]]$concepts[[3]]
# [[4]][[10]]$concepts[[3]]$id
# [1] "3461869"
#
# [[4]][[10]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[4]][[10]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[4]][[10]]$relationships
# [[4]][[10]]$relationships[[1]]
# [[4]][[10]]$relationships[[1]]$concept0Id
# [1] "4043331"
#
# [[4]][[10]]$relationships[[1]]$concept1Id
# [1] "4053505"
#
# [[4]][[10]]$relationships[[1]]$predicateIds
# [[4]][[10]]$relationships[[1]]$predicateIds[[1]]
# [1] "52"
#
#
#
# [[4]][[10]]$relationships[[2]]
# [[4]][[10]]$relationships[[2]]$concept0Id
# [1] "4053505"
#
# [[4]][[10]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[4]][[10]]$relationships[[2]]$predicateIds
# [[4]][[10]]$relationships[[2]]$predicateIds[[1]]
# [1] "29"
#
#
#
#
# [[4]][[10]]$score
# [1] 12.97584
#
#
#
# [[5]]
# [[5]][[1]]
# [[5]][[1]]$concepts
# [[5]][[1]]$concepts[[1]]
# [[5]][[1]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[1]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[1]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[1]]$concepts[[2]]
# [[5]][[1]]$concepts[[2]]$id
# [1] "774483"
#
# [[5]][[1]]$concepts[[2]]$name
# [1] "isobutyl alcohol"
#
# [[5]][[1]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[1]]$concepts[[3]]
# [[5]][[1]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[1]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[1]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[1]]$relationships
# [[5]][[1]]$relationships[[1]]
# [[5]][[1]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[1]]$relationships[[1]]$concept1Id
# [1] "774483"
#
# [[5]][[1]]$relationships[[1]]$predicateIds
# [[5]][[1]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[1]]$relationships[[2]]
# [[5]][[1]]$relationships[[2]]$concept0Id
# [1] "774483"
#
# [[5]][[1]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[1]]$relationships[[2]]$predicateIds
# [[5]][[1]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
# [[5]][[1]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[5]][[1]]$score
# [1] 10.30988
#
#
# [[5]][[2]]
# [[5]][[2]]$concepts
# [[5]][[2]]$concepts[[1]]
# [[5]][[2]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[2]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[2]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[2]]$concepts[[2]]
# [[5]][[2]]$concepts[[2]]$id
# [1] "1250983"
#
# [[5]][[2]]$concepts[[2]]$name
# [1] "5-hydroxymethylfurfural"
#
# [[5]][[2]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[2]]$concepts[[3]]
# [[5]][[2]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[2]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[2]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[2]]$relationships
# [[5]][[2]]$relationships[[1]]
# [[5]][[2]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[2]]$relationships[[1]]$concept1Id
# [1] "1250983"
#
# [[5]][[2]]$relationships[[1]]$predicateIds
# [[5]][[2]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[2]]$relationships[[2]]
# [[5]][[2]]$relationships[[2]]$concept0Id
# [1] "1250983"
#
# [[5]][[2]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[2]]$relationships[[2]]$predicateIds
# [[5]][[2]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
# [[5]][[2]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[5]][[2]]$score
# [1] 10.8972
#
#
# [[5]][[3]]
# [[5]][[3]]$concepts
# [[5]][[3]]$concepts[[1]]
# [[5]][[3]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[3]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[3]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[3]]$concepts[[2]]
# [[5]][[3]]$concepts[[2]]$id
# [1] "5210546"
#
# [[5]][[3]]$concepts[[2]]$name
# [1] "calcofluor white"
#
# [[5]][[3]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[3]]$concepts[[3]]
# [[5]][[3]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[3]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[3]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[3]]$relationships
# [[5]][[3]]$relationships[[1]]
# [[5]][[3]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[3]]$relationships[[1]]$concept1Id
# [1] "5210546"
#
# [[5]][[3]]$relationships[[1]]$predicateIds
# [[5]][[3]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[3]]$relationships[[2]]
# [[5]][[3]]$relationships[[2]]$concept0Id
# [1] "5210546"
#
# [[5]][[3]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[3]]$relationships[[2]]$predicateIds
# [[5]][[3]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[5]][[3]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[5]][[3]]$score
# [1] 11.36519
#
#
# [[5]][[4]]
# [[5]][[4]]$concepts
# [[5]][[4]]$concepts[[1]]
# [[5]][[4]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[4]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[4]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[4]]$concepts[[2]]
# [[5]][[4]]$concepts[[2]]$id
# [1] "4965352"
#
# [[5]][[4]]$concepts[[2]]$name
# [1] "artesunate"
#
# [[5]][[4]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[4]]$concepts[[3]]
# [[5]][[4]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[4]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[4]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[4]]$relationships
# [[5]][[4]]$relationships[[1]]
# [[5]][[4]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[4]]$relationships[[1]]$concept1Id
# [1] "4965352"
#
# [[5]][[4]]$relationships[[1]]$predicateIds
# [[5]][[4]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[4]]$relationships[[2]]
# [[5]][[4]]$relationships[[2]]$concept0Id
# [1] "4965352"
#
# [[5]][[4]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[4]]$relationships[[2]]$predicateIds
# [[5]][[4]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
#
#
#
# [[5]][[4]]$score
# [1] 11.44674
#
#
# [[5]][[5]]
# [[5]][[5]]$concepts
# [[5]][[5]]$concepts[[1]]
# [[5]][[5]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[5]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[5]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[5]]$concepts[[2]]
# [[5]][[5]]$concepts[[2]]$id
# [1] "5222812"
#
# [[5]][[5]]$concepts[[2]]$name
# [1] "trehalose"
#
# [[5]][[5]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[5]]$concepts[[3]]
# [[5]][[5]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[5]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[5]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[5]]$relationships
# [[5]][[5]]$relationships[[1]]
# [[5]][[5]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[5]]$relationships[[1]]$concept1Id
# [1] "5222812"
#
# [[5]][[5]]$relationships[[1]]$predicateIds
# [[5]][[5]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[5]]$relationships[[2]]
# [[5]][[5]]$relationships[[2]]$concept0Id
# [1] "5222812"
#
# [[5]][[5]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[5]]$relationships[[2]]$predicateIds
# [[5]][[5]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
#
#
#
# [[5]][[5]]$score
# [1] 11.79967
#
#
# [[5]][[6]]
# [[5]][[6]]$concepts
# [[5]][[6]]$concepts[[1]]
# [[5]][[6]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[6]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[6]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[6]]$concepts[[2]]
# [[5]][[6]]$concepts[[2]]$id
# [1] "922532"
#
# [[5]][[6]]$concepts[[2]]$name
# [1] "vitamin k 3"
#
# [[5]][[6]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[6]]$concepts[[3]]
# [[5]][[6]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[6]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[6]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[6]]$relationships
# [[5]][[6]]$relationships[[1]]
# [[5]][[6]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[6]]$relationships[[1]]$concept1Id
# [1] "922532"
#
# [[5]][[6]]$relationships[[1]]$predicateIds
# [[5]][[6]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[6]]$relationships[[2]]
# [[5]][[6]]$relationships[[2]]$concept0Id
# [1] "922532"
#
# [[5]][[6]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[6]]$relationships[[2]]$predicateIds
# [[5]][[6]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
#
#
#
# [[5]][[6]]$score
# [1] 12.55589
#
#
# [[5]][[7]]
# [[5]][[7]]$concepts
# [[5]][[7]]$concepts[[1]]
# [[5]][[7]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[7]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[7]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[7]]$concepts[[2]]
# [[5]][[7]]$concepts[[2]]$id
# [1] "720782"
#
# [[5]][[7]]$concepts[[2]]$name
# [1] "galactose"
#
# [[5]][[7]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[7]]$concepts[[3]]
# [[5]][[7]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[7]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[7]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[7]]$relationships
# [[5]][[7]]$relationships[[1]]
# [[5]][[7]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[7]]$relationships[[1]]$concept1Id
# [1] "720782"
#
# [[5]][[7]]$relationships[[1]]$predicateIds
# [[5]][[7]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[7]]$relationships[[2]]
# [[5]][[7]]$relationships[[2]]$concept0Id
# [1] "720782"
#
# [[5]][[7]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[7]]$relationships[[2]]$predicateIds
# [[5]][[7]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[5]][[7]]$relationships[[2]]$predicateIds[[2]]
# [1] "34"
#
#
#
#
# [[5]][[7]]$score
# [1] 12.62277
#
#
# [[5]][[8]]
# [[5]][[8]]$concepts
# [[5]][[8]]$concepts[[1]]
# [[5]][[8]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[8]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[8]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[8]]$concepts[[2]]
# [[5]][[8]]$concepts[[2]]$id
# [1] "4970313"
#
# [[5]][[8]]$concepts[[2]]$name
# [1] "sirolimus"
#
# [[5]][[8]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[8]]$concepts[[3]]
# [[5]][[8]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[8]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[8]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[8]]$relationships
# [[5]][[8]]$relationships[[1]]
# [[5]][[8]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[8]]$relationships[[1]]$concept1Id
# [1] "4970313"
#
# [[5]][[8]]$relationships[[1]]$predicateIds
# [[5]][[8]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[8]]$relationships[[2]]
# [[5]][[8]]$relationships[[2]]$concept0Id
# [1] "4970313"
#
# [[5]][[8]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[8]]$relationships[[2]]$predicateIds
# [[5]][[8]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
#
#
#
# [[5]][[8]]$score
# [1] 13.15983
#
#
# [[5]][[9]]
# [[5]][[9]]$concepts
# [[5]][[9]]$concepts[[1]]
# [[5]][[9]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[9]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[9]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[9]]$concepts[[2]]
# [[5]][[9]]$concepts[[2]]$id
# [1] "4056576"
#
# [[5]][[9]]$concepts[[2]]$name
# [1] "hydrogen peroxide"
#
# [[5]][[9]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[9]]$concepts[[3]]
# [[5]][[9]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[9]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[9]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[9]]$relationships
# [[5]][[9]]$relationships[[1]]
# [[5]][[9]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[9]]$relationships[[1]]$concept1Id
# [1] "4056576"
#
# [[5]][[9]]$relationships[[1]]$predicateIds
# [[5]][[9]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[9]]$relationships[[2]]
# [[5]][[9]]$relationships[[2]]$concept0Id
# [1] "4056576"
#
# [[5]][[9]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[9]]$relationships[[2]]$predicateIds
# [[5]][[9]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[5]][[9]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
# [[5]][[9]]$relationships[[2]]$predicateIds[[3]]
# [1] "109"
#
# [[5]][[9]]$relationships[[2]]$predicateIds[[4]]
# [1] "34"
#
# [[5]][[9]]$relationships[[2]]$predicateIds[[5]]
# [1] "34"
#
# [[5]][[9]]$relationships[[2]]$predicateIds[[6]]
# [1] "107"
#
#
#
#
# [[5]][[9]]$score
# [1] 13.92576
#
#
# [[5]][[10]]
# [[5]][[10]]$concepts
# [[5]][[10]]$concepts[[1]]
# [[5]][[10]]$concepts[[1]]$id
# [1] "4044162"
#
# [[5]][[10]]$concepts[[1]]$name
# [1] "msn2 (saccharomyces cerevisiae s288c)"
#
# [[5]][[10]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[5]][[10]]$concepts[[2]]
# [[5]][[10]]$concepts[[2]]$id
# [1] "1288761"
#
# [[5]][[10]]$concepts[[2]]$name
# [1] "sodium chloride"
#
# [[5]][[10]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[5]][[10]]$concepts[[3]]
# [[5]][[10]]$concepts[[3]]$id
# [1] "3461869"
#
# [[5]][[10]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[5]][[10]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[5]][[10]]$relationships
# [[5]][[10]]$relationships[[1]]
# [[5]][[10]]$relationships[[1]]$concept0Id
# [1] "4044162"
#
# [[5]][[10]]$relationships[[1]]$concept1Id
# [1] "1288761"
#
# [[5]][[10]]$relationships[[1]]$predicateIds
# [[5]][[10]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[5]][[10]]$relationships[[2]]
# [[5]][[10]]$relationships[[2]]$concept0Id
# [1] "1288761"
#
# [[5]][[10]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[5]][[10]]$relationships[[2]]$predicateIds
# [[5]][[10]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[5]][[10]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
# [[5]][[10]]$relationships[[2]]$predicateIds[[3]]
# [1] "34"
#
#
#
#
# [[5]][[10]]$score
# [1] 14.11182
#
#
#
# [[6]]
# [[6]][[1]]
# [[6]][[1]]$concepts
# [[6]][[1]]$concepts[[1]]
# [[6]][[1]]$concepts[[1]]$id
# [1] "4045917"
#
# [[6]][[1]]$concepts[[1]]$name
# [1] "dog1 (saccharomyces cerevisiae s288c)"
#
# [[6]][[1]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[6]][[1]]$concepts[[2]]
# [[6]][[1]]$concepts[[2]]$id
# [1] "774483"
#
# [[6]][[1]]$concepts[[2]]$name
# [1] "isobutyl alcohol"
#
# [[6]][[1]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[6]][[1]]$concepts[[3]]
# [[6]][[1]]$concepts[[3]]$id
# [1] "3461869"
#
# [[6]][[1]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[6]][[1]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[6]][[1]]$relationships
# [[6]][[1]]$relationships[[1]]
# [[6]][[1]]$relationships[[1]]$concept0Id
# [1] "4045917"
#
# [[6]][[1]]$relationships[[1]]$concept1Id
# [1] "774483"
#
# [[6]][[1]]$relationships[[1]]$predicateIds
# [[6]][[1]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[6]][[1]]$relationships[[2]]
# [[6]][[1]]$relationships[[2]]$concept0Id
# [1] "774483"
#
# [[6]][[1]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[6]][[1]]$relationships[[2]]$predicateIds
# [[6]][[1]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
# [[6]][[1]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
#
#
#
# [[6]][[1]]$score
# [1] 9.83778
#
#
# [[6]][[2]]
# [[6]][[2]]$concepts
# [[6]][[2]]$concepts[[1]]
# [[6]][[2]]$concepts[[1]]$id
# [1] "4045917"
#
# [[6]][[2]]$concepts[[1]]$name
# [1] "dog1 (saccharomyces cerevisiae s288c)"
#
# [[6]][[2]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[6]][[2]]$concepts[[2]]
# [[6]][[2]]$concepts[[2]]$id
# [1] "4056576"
#
# [[6]][[2]]$concepts[[2]]$name
# [1] "hydrogen peroxide"
#
# [[6]][[2]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[6]][[2]]$concepts[[3]]
# [[6]][[2]]$concepts[[3]]$id
# [1] "3461869"
#
# [[6]][[2]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[6]][[2]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[6]][[2]]$relationships
# [[6]][[2]]$relationships[[1]]
# [[6]][[2]]$relationships[[1]]$concept0Id
# [1] "4045917"
#
# [[6]][[2]]$relationships[[1]]$concept1Id
# [1] "4056576"
#
# [[6]][[2]]$relationships[[1]]$predicateIds
# [[6]][[2]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[6]][[2]]$relationships[[2]]
# [[6]][[2]]$relationships[[2]]$concept0Id
# [1] "4056576"
#
# [[6]][[2]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[6]][[2]]$relationships[[2]]$predicateIds
# [[6]][[2]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[6]][[2]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
# [[6]][[2]]$relationships[[2]]$predicateIds[[3]]
# [1] "109"
#
# [[6]][[2]]$relationships[[2]]$predicateIds[[4]]
# [1] "34"
#
# [[6]][[2]]$relationships[[2]]$predicateIds[[5]]
# [1] "34"
#
# [[6]][[2]]$relationships[[2]]$predicateIds[[6]]
# [1] "107"
#
#
#
#
# [[6]][[2]]$score
# [1] 13.45366
#
#
# [[6]][[3]]
# [[6]][[3]]$concepts
# [[6]][[3]]$concepts[[1]]
# [[6]][[3]]$concepts[[1]]$id
# [1] "4045917"
#
# [[6]][[3]]$concepts[[1]]$name
# [1] "dog1 (saccharomyces cerevisiae s288c)"
#
# [[6]][[3]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[6]][[3]]$concepts[[2]]
# [[6]][[3]]$concepts[[2]]$id
# [1] "1288761"
#
# [[6]][[3]]$concepts[[2]]$name
# [1] "sodium chloride"
#
# [[6]][[3]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[6]][[3]]$concepts[[3]]
# [[6]][[3]]$concepts[[3]]$id
# [1] "3461869"
#
# [[6]][[3]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[6]][[3]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[6]][[3]]$relationships
# [[6]][[3]]$relationships[[1]]
# [[6]][[3]]$relationships[[1]]$concept0Id
# [1] "4045917"
#
# [[6]][[3]]$relationships[[1]]$concept1Id
# [1] "1288761"
#
# [[6]][[3]]$relationships[[1]]$predicateIds
# [[6]][[3]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[6]][[3]]$relationships[[2]]
# [[6]][[3]]$relationships[[2]]$concept0Id
# [1] "1288761"
#
# [[6]][[3]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[6]][[3]]$relationships[[2]]$predicateIds
# [[6]][[3]]$relationships[[2]]$predicateIds[[1]]
# [1] "3"
#
# [[6]][[3]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
# [[6]][[3]]$relationships[[2]]$predicateIds[[3]]
# [1] "34"
#
#
#
#
# [[6]][[3]]$score
# [1] 13.63972
#
#
# [[6]][[4]]
# [[6]][[4]]$concepts
# [[6]][[4]]$concepts[[1]]
# [[6]][[4]]$concepts[[1]]$id
# [1] "4045917"
#
# [[6]][[4]]$concepts[[1]]$name
# [1] "dog1 (saccharomyces cerevisiae s288c)"
#
# [[6]][[4]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[6]][[4]]$concepts[[2]]
# [[6]][[4]]$concepts[[2]]$id
# [1] "4963555"
#
# [[6]][[4]]$concepts[[2]]$name
# [1] "ethanol"
#
# [[6]][[4]]$concepts[[2]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
# [[6]][[4]]$concepts[[3]]
# [[6]][[4]]$concepts[[3]]$id
# [1] "3461869"
#
# [[6]][[4]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[6]][[4]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[6]][[4]]$relationships
# [[6]][[4]]$relationships[[1]]
# [[6]][[4]]$relationships[[1]]$concept0Id
# [1] "4045917"
#
# [[6]][[4]]$relationships[[1]]$concept1Id
# [1] "4963555"
#
# [[6]][[4]]$relationships[[1]]$predicateIds
# [[6]][[4]]$relationships[[1]]$predicateIds[[1]]
# [1] "28"
#
#
#
# [[6]][[4]]$relationships[[2]]
# [[6]][[4]]$relationships[[2]]$concept0Id
# [1] "4963555"
#
# [[6]][[4]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[6]][[4]]$relationships[[2]]$predicateIds
# [[6]][[4]]$relationships[[2]]$predicateIds[[1]]
# [1] "34"
#
# [[6]][[4]]$relationships[[2]]$predicateIds[[2]]
# [1] "3"
#
# [[6]][[4]]$relationships[[2]]$predicateIds[[3]]
# [1] "109"
#
# [[6]][[4]]$relationships[[2]]$predicateIds[[4]]
# [1] "3"
#
# [[6]][[4]]$relationships[[2]]$predicateIds[[5]]
# [1] "109"
#
# [[6]][[4]]$relationships[[2]]$predicateIds[[6]]
# [1] "34"
#
#
#
#
# [[6]][[4]]$score
# [1] 13.71619
#
#
# [[6]][[5]]
# [[6]][[5]]$concepts
# [[6]][[5]]$concepts[[1]]
# [[6]][[5]]$concepts[[1]]$id
# [1] "4045917"
#
# [[6]][[5]]$concepts[[1]]$name
# [1] "dog1 (saccharomyces cerevisiae s288c)"
#
# [[6]][[5]]$concepts[[1]]$semanticCategory
# [1] "Genes & Molecular Sequences"
#
#
# [[6]][[5]]$concepts[[2]]
# [[6]][[5]]$concepts[[2]]$id
# [1] "4050444"
#
# [[6]][[5]]$concepts[[2]]$name
# [1] "metabolism"
#
# [[6]][[5]]$concepts[[2]]$semanticCategory
# [1] "Physiology"
#
#
# [[6]][[5]]$concepts[[3]]
# [[6]][[5]]$concepts[[3]]$id
# [1] "3461869"
#
# [[6]][[5]]$concepts[[3]]$name
# [1] "chemicals"
#
# [[6]][[5]]$concepts[[3]]$semanticCategory
# [1] "Chemicals & Drugs"
#
#
#
# [[6]][[5]]$relationships
# [[6]][[5]]$relationships[[1]]
# [[6]][[5]]$relationships[[1]]$concept0Id
# [1] "4045917"
#
# [[6]][[5]]$relationships[[1]]$concept1Id
# [1] "4050444"
#
# [[6]][[5]]$relationships[[1]]$predicateIds
# [[6]][[5]]$relationships[[1]]$predicateIds[[1]]
# [1] "52"
#
#
#
# [[6]][[5]]$relationships[[2]]
# [[6]][[5]]$relationships[[2]]$concept0Id
# [1] "4050444"
#
# [[6]][[5]]$relationships[[2]]$concept1Id
# [1] "3461869"
#
# [[6]][[5]]$relationships[[2]]$predicateIds
# [[6]][[5]]$relationships[[2]]$predicateIds[[1]]
# [1] "29"
#
#
#
#
# [[6]][[5]]$score
# [1] 13.7526

# %% [markdown]
# ## parse only the relationships

# %%
rel<-b[,2]

### collapse into a list
dfs<-do.call(rbind,rel)


tt<-fromJSON(toJSON(dfs),flatten = TRUE)
row.names(tt)<-NULL
colnames(tt)<-NULL

tt[,1]<-unlist(tt[,1])
tt[,2]<-unlist(tt[,2])
tt[,3]<-sapply(tt[,3], paste0, collapse=",")
colnames(tt)<-c("sub","obj","pred")

tt%>% mutate(pred=strsplit(as.character(pred),",")) %>% unnest(pred) -> tripleId
row.names(tt)<-NULL
tripleId<-tripleId[,c(1,3,2)]

# %% [markdown]
# ### Step 3: Map human redeable triples from the reference database

# %%
pred<-read.csv("Reference_Predicate_List.csv",header=TRUE)
pred<-pred[,c(2,3)]
colnames(pred)<-c("pred","names")

subject<-getConceptName(tripleId[,1])
object<-getConceptName(tripleId[,3])
predicate<-sqldf('select * from tripleId left join pred on pred.Pred=tripleId.Pred')

tripleName<-cbind(subject[,2],as.character(predicate[,5]),object[,2])

# %%
head(tripleName)
# Out:
#      [,1]                                  [,2]
# [1,] ucc1 (saccharomyces cerevisiae s288c) is functionally related to
# [2,] parachlorophenol                      interacts with
# [3,] ucc1 (saccharomyces cerevisiae s288c) is functionally related to
# [4,] 1-butanol                             interacts with
# [5,] 1-butanol                             is a
# [6,] ucc1 (saccharomyces cerevisiae s288c) is functionally related to
#      [,3]
# [1,] parachlorophenol
# [2,] chemicals
# [3,] 1-butanol
# [4,] chemicals
# [5,] chemicals
# [6,] toxaphene

# %% [markdown]
# ### Step 4: Write it to a file and Vizualize these in Triple Viewer and Spot

# %%
write.table(tripleName,file="./triple.csv",sep=";")
